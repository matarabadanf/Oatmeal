# %% [markdown]
# # Corrected MP2 test
#
#
# **NOTE: THESE RESULTS WORK OUT BECAUSE WE ARE USING THE `eig` SOLVER IN THE SCF FOR THE NON-SCALED CASE**
# ---
#
# Since (in theory), the definition of virtual orbitals is now correct, as the orthonormalization scheme should be working, and leading to MO coefficients that diagonalize the $F_MO$ matrix, but keep the correct energies, we will test the implementation against PySCF's using the SCF coefficients obtained from the current implementation.

# %%
from pyscf import gto, scf, mp
import numpy as np
from py_mods.src.MP2.CSMP2 import CS_MP2
from py_mods.src.SCF.CSRHF import CS_RHF
from py_mods.src.SCF.external import RHF_context_from_pyscf
import matplotlib.pyplot as plt

# %% [markdown]
# We will define the basis to use:

# %%
basis_names = [
    "cc-pvdz",
    "cc-pvtz",
    "cc-pvqz",
    "cc-pv5z",
    "aug-cc-pvdz",
    "aug-cc-pvtz",
    "aug-cc-pvqz",
    "aug-cc-pv5z",
    "def2-svp",
    "def2-tzvp",
    "def2-qzvp",
    "def2-svpd",
    "def2-tzvpd",
    "def2-qzvpd",
]

cc_basis = basis_names[0:8]

# %%
abs_errors = []
rel_errors = []
n_electrons = []

for basis in cc_basis:
    print(f'Calculating energy with {basis} basis set')

    pyscf_args = {
        "atom": "He 0 0 0",
        "spin": 0,
        "charge": 0,
        "basis": f"{basis}",
    }
    
    mol = gto.M(**pyscf_args) # , symmetry = False)
    mol.verbose = 0

    mf = scf.RHF(mol)
    
    # Tighten tighten tighten
    mf.conv_tol = 1e-14
    mf.conv_tol_grad = 1e-14
    mf.max_cycle = 100 

    e_He = mf.kernel()
    
    e_elec = mf.energy_elec()

    mymp = mp.RMP2(mf).run()  # this is UMP2

    # implementation and calculation
    RHF_cxt = RHF_context_from_pyscf(**pyscf_args)
    # RHF_cxt.conv_start = 30
    # RHF_cxt.conv_type = None
    RHF_cxt.threshold = 1e-14
    RHF_cxt.verbose = True

    RHF_res = CS_RHF(RHF_cxt)
    RHF_res.C_munu = RHF_res.C_munu.real

    # enforce pyscf mo energies and coefficients
    # RHF_res.C_munu = mf.mo_coeff
    # RHF_res.e_orb = mf.mo_energy
    
    mp_results = CS_MP2(RHF_res)

    abs_errors.append(mymp.e_tot - mp_results.E_MP2)
    rel_errors.append(np.abs((mp_results.E_MP2 - mymp.e_tot) * 100 / mymp.e_tot))
    
    if abs_errors[-1] > 1E-6:
        print(np.max(RHF_res.C_munu.imag))
    
    max_eorb_diff = max(abs(RHF_res.e_orb - mf.mo_energy))
    print('Max orbital energy error:', max_eorb_diff)
# Out:
# Calculating energy with cc-pvdz basis set
# --------------------------------------------------------------------------------------------------------------------------------
# |   Iter     |                   E_iter                      |                   Delta_e                   |      norm(e_i)      |
# --------------------------------------------------------------------------------------------------------------------------------
#       1     0.000000E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     0.0000E+00
#       2     -2.741897E+00+0.000000E+00j     -2.741897E+00+0.000000E+00j     7.3757E-01
#       3     -2.854410E+00+0.000000E+00j     -1.125131E-01+0.000000E+00j     6.1870E-02
#       4     -2.855156E+00+0.000000E+00j     -7.462188E-04+0.000000E+00j     4.7167E-03
#       5     -2.855160E+00+0.000000E+00j     -4.329924E-06+0.000000E+00j     3.5741E-04
#       6     -2.855160E+00+0.000000E+00j     -2.485967E-08+0.000000E+00j     2.7071E-05
#       7     -2.855160E+00+0.000000E+00j     -1.426126E-10+0.000000E+00j     2.0503E-06
#       8     -2.855160E+00+0.000000E+00j     -8.180123E-13+0.000000E+00j     1.5529E-07
#       9     -2.855160E+00+0.000000E+00j     -5.329071E-15+0.000000E+00j     1.1761E-08
#      10     -2.855160E+00+0.000000E+00j     -4.440892E-16+0.000000E+00j     8.9079E-10
#      11     -2.855160E+00+0.000000E+00j     8.881784E-16+0.000000E+00j     6.7466E-11
#      12     -2.855160E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     5.1089E-12
#      13     -2.855160E+00+0.000000E+00j     4.440892E-16+0.000000E+00j     3.8624E-13
#      14     -2.855160E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     2.8744E-14
# ------------------------------    STARTED DIIS   ------------------------------
#      15     -2.855160E+00+0.000000E+00j     -4.440892E-16+0.000000E+00j     2.3394E-15
# Convergence achieved after 15 iterations.
# Max orbital energy error: 6.661338147750939e-15
# Calculating energy with cc-pvtz basis set
# --------------------------------------------------------------------------------------------------------------------------------
# |   Iter     |                   E_iter                      |                   Delta_e                   |      norm(e_i)      |
# --------------------------------------------------------------------------------------------------------------------------------
#       1     0.000000E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     0.0000E+00
#       2     -2.752096E+00+0.000000E+00j     -2.752096E+00+0.000000E+00j     1.1741E+00
#       3     -2.859776E+00+0.000000E+00j     -1.076793E-01+0.000000E+00j     9.7425E-02
#       4     -2.861121E+00+0.000000E+00j     -1.344947E-03+0.000000E+00j     1.0540E-02
#       5     -2.861152E+00+0.000000E+00j     -3.178383E-05+0.000000E+00j     1.5968E-03
#       6     -2.861153E+00+0.000000E+00j     -9.249841E-07+0.000000E+00j     2.6912E-04
#       7     -2.861153E+00+0.000000E+00j     -2.769173E-08+0.000000E+00j     4.6328E-05
#       8     -2.861153E+00+0.000000E+00j     -8.313545E-10+0.000000E+00j     8.0133E-06
#       9     -2.861153E+00+0.000000E+00j     -2.496403E-11+0.000000E+00j     1.3879E-06
#      10     -2.861153E+00+0.000000E+00j     -7.496226E-13+0.000000E+00j     2.4046E-07
#      11     -2.861153E+00+0.000000E+00j     -2.264855E-14+0.000000E+00j     4.1667E-08
#      12     -2.861153E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     7.2203E-09
#      13     -2.861153E+00+0.000000E+00j     4.440892E-16+0.000000E+00j     1.2512E-09
#      14     -2.861153E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     2.1682E-10
# ------------------------------    STARTED DIIS   ------------------------------
#      15     -2.861153E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     3.7573E-11
#      16     -2.861153E+00+0.000000E+00j     8.881784E-16+0.000000E+00j     7.9448E-12
#      17     -2.861153E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     6.9022E-13
#      18     -2.861153E+00+0.000000E+00j     8.881784E-16+0.000000E+00j     9.7319E-14
#      19     -2.861153E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     1.7463E-14
#      20     -2.861153E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     4.0361E-15
# Convergence achieved after 20 iterations.
# Max orbital energy error: 1.687538997430238e-14
# Calculating energy with cc-pvqz basis set
# --------------------------------------------------------------------------------------------------------------------------------
# |   Iter     |                   E_iter                      |                   Delta_e                   |      norm(e_i)      |
# --------------------------------------------------------------------------------------------------------------------------------
#       1     0.000000E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     0.0000E+00
#       2     -2.750138E+00+0.000000E+00j     -2.750138E+00+0.000000E+00j     1.6570E+00
#       3     -2.860139E+00+0.000000E+00j     -1.100010E-01+0.000000E+00j     1.2436E-01
#       4     -2.861481E+00+0.000000E+00j     -1.342423E-03+0.000000E+00j     1.3808E-02
#       5     -2.861513E+00+0.000000E+00j     -3.210857E-05+0.000000E+00j     2.2763E-03
#       6     -2.861514E+00+0.000000E+00j     -1.110485E-06+0.000000E+00j     4.2153E-04
#       7     -2.861514E+00+0.000000E+00j     -4.213368E-08+0.000000E+00j     8.0819E-05
#       8     -2.861514E+00+0.000000E+00j     -1.628149E-09+0.000000E+00j     1.5725E-05
#       9     -2.861514E+00+0.000000E+00j     -6.313483E-11+0.000000E+00j     3.0805E-06
#      10     -2.861514E+00+0.000000E+00j     -2.450484E-12+0.000000E+00j     6.0535E-07
#      11     -2.861514E+00+0.000000E+00j     -9.547918E-14+0.000000E+00j     1.1912E-07
#      12     -2.861514E+00+0.000000E+00j     -3.552714E-15+0.000000E+00j     2.3456E-08
#      13     -2.861514E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     4.6198E-09
#      14     -2.861514E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     9.1000E-10
# ------------------------------    STARTED DIIS   ------------------------------
#      15     -2.861514E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     1.7925E-10
#      16     -2.861514E+00+0.000000E+00j     -4.440892E-16+0.000000E+00j     3.6404E-13
#      17     -2.861514E+00+0.000000E+00j     1.332268E-15+0.000000E+00j     3.0432E-14
#      18     -2.861514E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     8.2033E-15
# Convergence achieved after 18 iterations.
# Max orbital energy error: 4.618527782440651e-14
# Calculating energy with cc-pv5z basis set
# --------------------------------------------------------------------------------------------------------------------------------
# |   Iter     |                   E_iter                      |                   Delta_e                   |      norm(e_i)      |
# --------------------------------------------------------------------------------------------------------------------------------
#       1     0.000000E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     0.0000E+00
#       2     -2.750010E+00+0.000000E+00j     -2.750010E+00+0.000000E+00j     2.0540E+00
#       3     -2.860252E+00+0.000000E+00j     -1.102420E-01+0.000000E+00j     1.4406E-01
#       4     -2.861591E+00+0.000000E+00j     -1.339265E-03+0.000000E+00j     1.6541E-02
#       5     -2.861624E+00+0.000000E+00j     -3.265637E-05+0.000000E+00j     2.8283E-03
#       6     -2.861625E+00+0.000000E+00j     -1.191581E-06+0.000000E+00j     5.3257E-04
#       7     -2.861625E+00+0.000000E+00j     -4.916405E-08+0.000000E+00j     1.0448E-04
#       8     -2.861625E+00+0.000000E+00j     -2.096866E-09+0.000000E+00j     2.1024E-05
#       9     -2.861625E+00+0.000000E+00j     -9.023271E-11+0.000000E+00j     4.2936E-06
#      10     -2.861625E+00+0.000000E+00j     -3.892442E-12+0.000000E+00j     8.8403E-07
#      11     -2.861625E+00+0.000000E+00j     -1.683098E-13+0.000000E+00j     1.8281E-07
#      12     -2.861625E+00+0.000000E+00j     -7.105427E-15+0.000000E+00j     3.7892E-08
#      13     -2.861625E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     7.8632E-09
#      14     -2.861625E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     1.6328E-09
# ------------------------------    STARTED DIIS   ------------------------------
#      15     -2.861625E+00+0.000000E+00j     4.440892E-16+0.000000E+00j     3.3914E-10
#      16     -2.861625E+00+0.000000E+00j     -4.440892E-16+0.000000E+00j     1.5373E-14
#      17     -2.861625E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     3.2395E-14
#      18     -2.861625E+00+0.000000E+00j     4.440892E-16+0.000000E+00j     1.0830E-14
#      19     -2.861625E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     3.1485E-14
#      20     -2.861625E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     2.4443E-14
#      21     -2.861625E+00+0.000000E+00j     1.332268E-15+0.000000E+00j     8.1248E-15
# Convergence achieved after 21 iterations.
# Max orbital energy error: 1.3500311979441904e-13
# Calculating energy with aug-cc-pvdz basis set
# --------------------------------------------------------------------------------------------------------------------------------
# |   Iter     |                   E_iter                      |                   Delta_e                   |      norm(e_i)      |
# --------------------------------------------------------------------------------------------------------------------------------
#       1     0.000000E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     0.0000E+00
#       2     -2.742553E+00+0.000000E+00j     -2.742553E+00+0.000000E+00j     8.9966E-01
#       3     -2.854634E+00+0.000000E+00j     -1.120812E-01+0.000000E+00j     9.2644E-02
#       4     -2.855683E+00+0.000000E+00j     -1.049348E-03+0.000000E+00j     1.1036E-02
#       5     -2.855704E+00+0.000000E+00j     -2.030976E-05+0.000000E+00j     1.8660E-03
#       6     -2.855705E+00+0.000000E+00j     -8.455173E-07+0.000000E+00j     3.8384E-04
#       7     -2.855705E+00+0.000000E+00j     -4.203088E-08+0.000000E+00j     8.4198E-05
#       8     -2.855705E+00+0.000000E+00j     -2.134398E-09+0.000000E+00j     1.8830E-05
#       9     -2.855705E+00+0.000000E+00j     -1.086282E-10+0.000000E+00j     4.2365E-06
#      10     -2.855705E+00+0.000000E+00j     -5.530243E-12+0.000000E+00j     9.5500E-07
#      11     -2.855705E+00+0.000000E+00j     -2.806644E-13+0.000000E+00j     2.1541E-07
#      12     -2.855705E+00+0.000000E+00j     -1.465494E-14+0.000000E+00j     4.8596E-08
#      13     -2.855705E+00+0.000000E+00j     -1.332268E-15+0.000000E+00j     1.0964E-08
#      14     -2.855705E+00+0.000000E+00j     8.881784E-16+0.000000E+00j     2.4737E-09
# ------------------------------    STARTED DIIS   ------------------------------
#      15     -2.855705E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     5.5812E-10
#      16     -2.855705E+00+0.000000E+00j     4.440892E-16+0.000000E+00j     2.1665E-11
#      17     -2.855705E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     2.6082E-12
#      18     -2.855705E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     4.5636E-13
#      19     -2.855705E+00+0.000000E+00j     8.881784E-16+0.000000E+00j     9.5524E-14
#      20     -2.855705E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     2.1792E-14
#      21     -2.855705E+00+0.000000E+00j     1.332268E-15+0.000000E+00j     4.3199E-15
# Convergence achieved after 21 iterations.
# Max orbital energy error: 4.440892098500626e-15
# Calculating energy with aug-cc-pvtz basis set
# --------------------------------------------------------------------------------------------------------------------------------
# |   Iter     |                   E_iter                      |                   Delta_e                   |      norm(e_i)      |
# --------------------------------------------------------------------------------------------------------------------------------
#       1     0.000000E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     0.0000E+00
#       2     -2.752109E+00+0.000000E+00j     -2.752109E+00+0.000000E+00j     1.2975E+00
#       3     -2.859789E+00+0.000000E+00j     -1.076794E-01+0.000000E+00j     1.2219E-01
#       4     -2.861147E+00+0.000000E+00j     -1.358610E-03+0.000000E+00j     1.6109E-02
#       5     -2.861182E+00+0.000000E+00j     -3.486718E-05+0.000000E+00j     2.9039E-03
#       6     -2.861183E+00+0.000000E+00j     -1.236110E-06+0.000000E+00j     5.8199E-04
#       7     -2.861183E+00+0.000000E+00j     -5.002233E-08+0.000000E+00j     1.2110E-04
#       8     -2.861183E+00+0.000000E+00j     -2.186045E-09+0.000000E+00j     2.5670E-05
#       9     -2.861183E+00+0.000000E+00j     -9.991652E-11+0.000000E+00j     5.5024E-06
#      10     -2.861183E+00+0.000000E+00j     -4.678480E-12+0.000000E+00j     1.1878E-06
#      11     -2.861183E+00+0.000000E+00j     -2.229328E-13+0.000000E+00j     2.5763E-07
#      12     -2.861183E+00+0.000000E+00j     -9.325873E-15+0.000000E+00j     5.6056E-08
#      13     -2.861183E+00+0.000000E+00j     -4.440892E-16+0.000000E+00j     1.2223E-08
#      14     -2.861183E+00+0.000000E+00j     -4.440892E-16+0.000000E+00j     2.6692E-09
# ------------------------------    STARTED DIIS   ------------------------------
#      15     -2.861183E+00+0.000000E+00j     -4.440892E-16+0.000000E+00j     5.8345E-10
#      16     -2.861183E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     1.8150E-13
#      17     -2.861183E+00+0.000000E+00j     8.881784E-16+0.000000E+00j     2.1525E-14
#      18     -2.861183E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     5.2772E-15
# Convergence achieved after 18 iterations.
# Max orbital energy error: 3.019806626980426e-14
# Calculating energy with aug-cc-pvqz basis set
# --------------------------------------------------------------------------------------------------------------------------------
# |   Iter     |                   E_iter                      |                   Delta_e                   |      norm(e_i)      |
# --------------------------------------------------------------------------------------------------------------------------------
#       1     0.000000E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     0.0000E+00
#       2     -2.750163E+00+0.000000E+00j     -2.750163E+00+0.000000E+00j     1.7823E+00
#       3     -2.860143E+00+0.000000E+00j     -1.099800E-01+0.000000E+00j     1.4876E-01
#       4     -2.861488E+00+0.000000E+00j     -1.345113E-03+0.000000E+00j     1.8880E-02
#       5     -2.861521E+00+0.000000E+00j     -3.297553E-05+0.000000E+00j     3.4027E-03
#       6     -2.861522E+00+0.000000E+00j     -1.230600E-06+0.000000E+00j     6.8836E-04
#       7     -2.861522E+00+0.000000E+00j     -5.314616E-08+0.000000E+00j     1.4541E-04
#       8     -2.861522E+00+0.000000E+00j     -2.434216E-09+0.000000E+00j     3.1338E-05
#       9     -2.861522E+00+0.000000E+00j     -1.148837E-10+0.000000E+00j     6.8236E-06
#      10     -2.861522E+00+0.000000E+00j     -5.511591E-12+0.000000E+00j     1.4943E-06
#      11     -2.861522E+00+0.000000E+00j     -2.677858E-13+0.000000E+00j     3.2833E-07
#      12     -2.861522E+00+0.000000E+00j     -1.199041E-14+0.000000E+00j     7.2301E-08
#      13     -2.861522E+00+0.000000E+00j     -4.440892E-16+0.000000E+00j     1.5944E-08
#      14     -2.861522E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     3.5194E-09
# ------------------------------    STARTED DIIS   ------------------------------
#      15     -2.861522E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     7.7743E-10
#      16     -2.861522E+00+0.000000E+00j     4.440892E-16+0.000000E+00j     2.2226E-13
#      17     -2.861522E+00+0.000000E+00j     -4.440892E-16+0.000000E+00j     4.0008E-14
#      18     -2.861522E+00+0.000000E+00j     1.332268E-15+0.000000E+00j     1.0643E-14
#      19     -2.861522E+00+0.000000E+00j     -1.332268E-15+0.000000E+00j     1.7751E-14
#      20     -2.861522E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     9.3966E-15
# Convergence achieved after 20 iterations.
# Max orbital energy error: 6.750155989720952e-14
# Calculating energy with aug-cc-pv5z basis set
# --------------------------------------------------------------------------------------------------------------------------------
# |   Iter     |                   E_iter                      |                   Delta_e                   |      norm(e_i)      |
# --------------------------------------------------------------------------------------------------------------------------------
#       1     0.000000E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     0.0000E+00
#       2     -2.750001E+00+0.000000E+00j     -2.750001E+00+0.000000E+00j     2.1811E+00
#       3     -2.860253E+00+0.000000E+00j     -1.102520E-01+0.000000E+00j     1.6818E-01
#       4     -2.861593E+00+0.000000E+00j     -1.339769E-03+0.000000E+00j     2.1303E-02
#       5     -2.861626E+00+0.000000E+00j     -3.289575E-05+0.000000E+00j     3.8593E-03
#       6     -2.861627E+00+0.000000E+00j     -1.239414E-06+0.000000E+00j     7.7670E-04
#       7     -2.861627E+00+0.000000E+00j     -5.458191E-08+0.000000E+00j     1.6375E-04
#       8     -2.861627E+00+0.000000E+00j     -2.554758E-09+0.000000E+00j     3.5387E-05
#       9     -2.861627E+00+0.000000E+00j     -1.229785E-10+0.000000E+00j     7.7482E-06
#      10     -2.861627E+00+0.000000E+00j     -6.004974E-12+0.000000E+00j     1.7085E-06
#      11     -2.861627E+00+0.000000E+00j     -2.962075E-13+0.000000E+00j     3.7820E-07
#      12     -2.861627E+00+0.000000E+00j     -1.465494E-14+0.000000E+00j     8.3912E-08
#      13     -2.861627E+00+0.000000E+00j     0.000000E+00+0.000000E+00j     1.8644E-08
#      14     -2.861627E+00+0.000000E+00j     -1.332268E-15+0.000000E+00j     4.1459E-09
# ------------------------------    STARTED DIIS   ------------------------------
#      15     -2.861627E+00+0.000000E+00j     1.776357E-15+0.000000E+00j     9.2252E-10
#      16     -2.861627E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     1.6405E-14
#      17     -2.861627E+00+0.000000E+00j     -1.332268E-15+0.000000E+00j     1.3382E-14
#      18     -2.861627E+00+0.000000E+00j     1.776357E-15+0.000000E+00j     3.9673E-14
#      19     -2.861627E+00+0.000000E+00j     -8.881784E-16+0.000000E+00j     4.7029E-14
#      20     -2.861627E+00+0.000000E+00j     1.332268E-15+0.000000E+00j     7.7891E-15
# Convergence achieved after 20 iterations.
# Max orbital energy error: 4.973799150320701e-13

# %% [markdown]
# ---
#
# These are outputs for both cases using `eig` and `eigh`. The orbital energy differences with the reference are:
#
# ```
# # Output Using eig:
# Max orbital energy error: 1.0377032566566413e-11
# Max orbital energy error: 1.6783445744295022e-09
# Max orbital energy error: 1.3538103971200144e-08
# Max orbital energy error: 5.896890797885135e-08
# Max orbital energy error: 4.5296184580934096e-09
# Max orbital energy error: 1.3467721871052163e-07
# Max orbital energy error: 1.0339384104440796e-07
# Max orbital energy error: 1.3600084969311865e-07
# Max orbital energy error: 8.745226764972358e-12
#
# # Output using eigh:
# Max orbital energy error: 1.0377032566566413e-11
# Max orbital energy error: 1.678336580823725e-09
# Max orbital energy error: 1.3538105747556983e-08
# Max orbital energy error: 5.896893640056078e-08
# Max orbital energy error: 4.52961668173657e-09
# Max orbital energy error: 1.346772311450195e-07
# Max orbital energy error: 1.0339384104440796e-07
# Max orbital energy error: 1.3600089943111016e-07
# Max orbital energy error: 8.745670854182208e-12
# ```
#
# Conclusion: both eig and eigh yield the correct eigenvalues and orbital energies are not a good metric to compare diagonalization schemes.
#
#
# However, the resulting eigenvectors are not the same and result in MP2 errors. Using `eig`:
#
# ![image.png](attachment:image.png)
#
#
# and using `eigh`:
#
# ![image-2.png](attachment:image-2.png)
#
# however, enforcing pyscf's mo energies and coefficients:
#
# ![image-3.png](attachment:image-3.png)
#
# Thus the MP2 logic is correct. There must be something else going on in the SCF level.

# %%
abs_errors = [abs(i) for i in abs_errors]
plt.plot(cc_basis, np.array(abs_errors).real, marker="o", linestyle="-")

plt.title(f"He MP2 implementation error with different basis sets")
plt.yscale('log')
plt.ylabel("Absolute value of MP2 error / Hartree")
plt.xlabel("Atom")
plt.xticks(rotation=45)

plt.show()

# %%
print(max(abs_errors))
# Out:
# 3.9968028886505635e-15

# %%
abs_errors = []
rel_errors = []
n_electrons = []

for basis in cc_basis:
    print(f'Calculating energy with {basis} basis set')

    pyscf_args = {
        "atom": "Ne 0 0 0",
        "spin": 0,
        "charge": 0,
        "basis": f"{basis}",
    }
    
    mol = gto.M(**pyscf_args)
    mol.verbose = 0

    mf = scf.RHF(mol)
    
    # Tighten tighten tighten
    mf.conv_tol = 1e-14    
    mf.conv_tol_grad = 1e-14 
    mf.max_cycle = 100 

    e_He = mf.kernel()
    e_elec = mf.energy_elec()

    mymp = mp.RMP2(mf).run()  # this is UMP2

    n_electrons.append(mol.nelectron)

    # implementation and calculation
    RHF_cxt = RHF_context_from_pyscf(**pyscf_args)
    # RHF_cxt.threshold = 1e-8

    RHF_res = CS_RHF(RHF_cxt)
    mp_results = CS_MP2(RHF_res)

    abs_errors.append(mymp.e_tot - mp_results.E_MP2)
    rel_errors.append(np.abs((mp_results.E_MP2 - mymp.e_tot) * 100 / mymp.e_tot))

    if abs_errors[-1] > 1E-6:
        print(np.max(RHF_res.C_munu.imag))
# Out:
# Calculating energy with cc-pvdz basis set
# Calculating energy with cc-pvtz basis set
# Calculating energy with cc-pvqz basis set
# Calculating energy with cc-pv5z basis set
# 0.5737897681425441
# Calculating energy with aug-cc-pvdz basis set
# Calculating energy with aug-cc-pvtz basis set
# Calculating energy with aug-cc-pvqz basis set
# Calculating energy with aug-cc-pv5z basis set
# 0.7690833473433432

# %%
abs_errors = [abs(i) for i in abs_errors]
plt.plot(cc_basis, np.array(abs_errors).real, marker="o", linestyle="-")

plt.title(f"Ne MP2 implementation error with different basis sets")
plt.yscale('log')
plt.ylabel("Absolute value of MP2 error / Hartree")
plt.xlabel("Atom")
plt.xticks(rotation=45)

plt.show()

# %%
abs_errors = []
rel_errors = []
n_electrons = []

for basis in cc_basis:
    print(f'Calculating energy with {basis} basis set')

    pyscf_args = {
        "atom": "Ar 0 0 0",
        "spin": 0,
        "charge": 0,
        "basis": f"{basis}",
    }
    
    mol = gto.M(**pyscf_args)
    mol.verbose = 0

    mf = scf.RHF(mol)

    # Tighten tighten tighten
    mf.conv_tol = 1e-14    
    mf.conv_tol_grad = 1e-14 
    mf.max_cycle = 100 

    e_He = mf.kernel()

    e_He = mf.kernel()
    e_elec = mf.energy_elec()

    mymp = mp.RMP2(mf).run()  # this is UMP2

    n_electrons.append(mol.nelectron)

    # implementation and calculation
    RHF_cxt = RHF_context_from_pyscf(**pyscf_args)
    # RHF_cxt.threshold = 1e-7
    
    RHF_res = CS_RHF(RHF_cxt)
    mp_results = CS_MP2(RHF_res)

    abs_errors.append(mymp.e_tot - mp_results.E_MP2)
    rel_errors.append(np.abs((mp_results.E_MP2 - mymp.e_tot) * 100 / mymp.e_tot))
    if abs_errors[-1] > 1E-6:
        print(np.max(RHF_res.C_munu.imag))
# Out:
# Calculating energy with cc-pvdz basis set
# Calculating energy with cc-pvtz basis set
# Calculating energy with cc-pvqz basis set
# Calculating energy with cc-pv5z basis set
# 0.021727508433872444
# Calculating energy with aug-cc-pvdz basis set
# Calculating energy with aug-cc-pvtz basis set
# Calculating energy with aug-cc-pvqz basis set
# Calculating energy with aug-cc-pv5z basis set
# 0.7088952795413532

# %%
abs_errors = [abs(i) for i in abs_errors]
plt.plot(cc_basis, np.array(abs_errors).real, marker="o", linestyle="-")

plt.title(f"Ar MP2 implementation error with different basis sets")
plt.yscale("log")
plt.ylabel("Absolute value of MP2 error / Hartree")
plt.xlabel("Atom")
plt.xticks(rotation=45)

plt.show()
