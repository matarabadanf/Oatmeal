# %% [markdown]
# # CS-RMP2 Result comparison
# Results of the implementation compared to those obtained with [Qchem](https://doi.org/10.1080/00268976.2014.952696).

# %%
import numpy as np
import matplotlib.pyplot as plt
from pyscf import gto
from py_mods.src.SCF.basis_utils import even_temp_uncontr_str
from py_mods.src.SCF.CSRHF import RHF_theta_traj, CS_RHF_ContextClass, CS_RHF
from Dev.CSMP2_dev import CS_MP2
from py_mods.src.SCF.external import RHF_context_from_pyscf

# %% [markdown]
# # Definition of basis and intgrals

# %%
He_tempered_str = even_temp_uncontr_str(
    "He", "S", 7.668876968794860e-002, 1.9581497063588078, 21
)  # because this is the reference data

mol_He_even = gto.M(
    atom="He 0 0 0",
    spin=0,
    charge=0,
)  # basis='aug-cc-pVqZ')

mol_He_even.basis = {"He": gto.basis.parse(He_tempered_str)}
mol_He_even.build()

T_even_H2 = mol_He_even.intor("int1e_kin")
V_even_H2 = mol_He_even.intor("int1e_nuc")
S_even_H2 = mol_He_even.intor("int1e_ovlp")
eri_even_H2 = mol_He_even.intor("int2e")
# Out:
# -2.568 0.672000000000001

# %%
large_basis = """
He    S
      5.285000E+02           0.000000E+00           9.400000E-04           0.000000E+00           0.000000E+00
      7.931000E+01           0.000000E+00           7.214000E-03           0.000000E+00           0.000000E+00
      1.805000E+01           0.000000E+00           3.597500E-02           0.000000E+00           0.000000E+00
      5.085000E+00           0.000000E+00           1.277820E-01           0.000000E+00           0.000000E+00
      1.609000E+00           1.000000E+00           3.084700E-01           0.000000E+00           0.000000E+00
      5.363000E-01           0.000000E+00           4.530520E-01           1.000000E+00           0.000000E+00
      1.833000E-01           0.000000E+00           2.388840E-01           0.000000E+00           1.000000E+00
He    S
      0.0481900              1.0000000
He    P
      5.994000E+00           1.000000E+00           0.000000E+00           0.000000E+00
      1.745000E+00           0.000000E+00           1.000000E+00           0.000000E+00
      5.600000E-01           0.000000E+00           0.000000E+00           1.000000E+00
He    P
      0.1626000              1.0000000
He    D
      4.299000E+00           1.000000E+00           0.000000E+00
      1.223000E+00           0.000000E+00           1.000000E+00
He    D
      0.3510000              1.0000000
He    F
      2.680000E+00           1.0000000
He    F
      0.6906000              1.0000000
END
"""

mol_He_qz = gto.M(
    atom="He 0 0 0",
    spin=0,
    charge=0,
)  # basis='aug-cc-pVqZ')

mol_He_qz.basis = {"He": gto.basis.parse(large_basis)}
mol_He_qz.build()

T_qz_H2 = mol_He_qz.intor("int1e_kin")
V_qz_H2 = mol_He_qz.intor("int1e_nuc")
S_qz_H2 = mol_He_qz.intor("int1e_ovlp")
eri_qz_H2 = mol_He_qz.intor("int2e")

# %%
def load_traj(filename):
    with open(filename) as f:
        cont = f.readlines()
    cont = [line.strip().replace("(", "").replace(")", "") for line in cont]
    thetas = np.array([int(line.split(";")[0]) for line in cont])
    eners = [
        line.split(";")[1].strip().replace(" ", "").replace(",", "+").replace("+-", "-")
        + "j"
        for line in cont
    ]
    eners = np.array([complex(a) for a in eners])

    return thetas, eners

# %% [markdown]
# # 2s1 Helium
# ## Even-tempered basis

# %%
He_2s2_qz_gs_xt = CS_RHF_ContextClass(
S_qz_H2,
T_qz_H2,
V_qz_H2,
eri_qz_H2,
2,
max_iter=1000,
# threshold=2e-10,
# conv_type="CROP",
theta=0.01
)

res = CS_RHF(He_2s2_qz_gs_xt)
mp2_res = CS_MP2(res)
print(res.e_orb.T)
# Out:
# [-0.91793256+5.68034835e-06j  0.09871581-2.42252464e-03j
#   0.34776625-6.47500020e-03j  0.34776625-6.47500020e-03j
#   0.34776625-6.47500020e-03j  0.68519451-1.69382481e-02j
#   1.14874718-2.24162064e-02j  1.14874718-2.24162064e-02j
#   1.14874718-2.24162064e-02j  1.14874718-2.24162064e-02j
#   1.14874718-2.24162064e-02j  1.47579723-2.86019422e-02j
#   1.47579723-2.86019422e-02j  1.47579723-2.86019422e-02j
#   2.95497077-6.80835921e-02j  3.00262996-5.91382119e-02j
#   3.00262996-5.91382119e-02j  3.00262996-5.91382119e-02j
#   3.00262996-5.91382119e-02j  3.00262996-5.91382119e-02j
#   3.00262996-5.91382119e-02j  3.00262996-5.91382119e-02j
#   4.57642802-8.96266202e-02j  4.57642802-8.96266202e-02j
#   4.57642802-8.96266202e-02j  4.57642802-8.96266202e-02j
#   4.57642802-8.96266202e-02j  5.1292926 -1.02849212e-01j
#   5.1292926 -1.02849212e-01j  5.1292926 -1.02849212e-01j
#  12.53328377-2.48042813e-01j 12.53328377-2.48042813e-01j
#  12.53328377-2.48042813e-01j 12.53328377-2.48042813e-01j
#  12.53328377-2.48042813e-01j 12.53328377-2.48042813e-01j
#  12.53328377-2.48042813e-01j 13.61790901-3.20840271e-01j
#  16.640247  -3.33063139e-01j 16.640247  -3.33063139e-01j
#  16.640247  -3.33063139e-01j 16.640247  -3.33063139e-01j
#  16.640247  -3.33063139e-01j 18.08788921-3.72338017e-01j
#  18.08788921-3.72338017e-01j 18.08788921-3.72338017e-01j]

# %%
w1, k1 = load_traj("data2/He_1s2_eventemp_mp2_qchem.dat")

# %%
He_2s2_even_gs_xt = CS_RHF_ContextClass(
    S_even_H2,
    T_even_H2,
    V_even_H2,
    eri_even_H2,
    2,
    max_iter=1000,
    threshold=2e-10,
    conv_type="CROP",
)

thetas = np.linspace(0, 0.8, 9)

He_2s2_even_gs = []

for theta in thetas:
    He_2s2_even_gs_xt = CS_RHF_ContextClass(
    S_qz_H2,
    T_qz_H2,
    V_qz_H2,
    eri_qz_H2,
    2,
    max_iter=1000,
    # threshold=2e-10,
    # conv_type="CROP",
    theta=theta,
    )

    res = CS_RHF(He_2s2_even_gs_xt)
    mp2_res = CS_MP2(res)
    He_2s2_even_gs.append(mp2_res.E_MP2)

He_2s2_even_gs = np.array(He_2s2_even_gs[:-2])
print(He_2s2_even_gs)
# Out:
# [-2.89724613+0.j         -2.89663619-0.00690738j -2.89475365-0.01369807j
#  -2.89144047-0.02024403j -2.88642526-0.02646999j -2.87927121-0.03260278j
#  -2.86916237-0.03966021j]

# %%
plt.scatter(k1.real, k1.imag, label="Qchem data", marker="o", c="orange")
plt.scatter(
    He_2s2_even_gs.real,
    He_2s2_even_gs.imag,
    label="Implemetation",
    c="RebeccaPurple",
    marker="x",
)

plt.legend()
plt.xlabel("Re(Ener)")
plt.ylabel("Im(Ener)")
plt.show()

# %%
error = He_2s2_even_gs - k1
print(f"Mean error: {np.mean(error): 6.4E}")
print(f"Max error:  {np.max(error): 6.4E}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 error = He_2s2_even_gs - k1
#       2 print(f"Mean error: {np.mean(error): 6.4E}")
#       3 print(f"Max error:  {np.max(error): 6.4E}")
#
# ValueError: operands could not be broadcast together with shapes (7,) (9,)

# %% [markdown]
# ## Augmented aug-cc-pV5Z

# %%
w2, k2 = load_traj("data/CSHF_QCHEM/He_1s2_augqz_qchem.dat")

# %%
He_2s2_qz_gs_ctx = CS_RHF_ContextClass(
    S_qz_H2, T_qz_H2, V_qz_H2, eri_qz_H2, n_electrons=2
)

traj_ener_2 = RHF_theta_traj(0.08, 9, He_2s2_qz_gs_ctx)

He_2s2_qz_gs = np.array(traj_ener_2[1])

# %%
plt.scatter(k2.real, k2.imag, label="Qchem data", marker="o", c="orange")
plt.scatter(
    He_2s2_qz_gs.real,
    He_2s2_qz_gs.imag,
    label="Implemetation",
    c="RebeccaPurple",
    marker="x",
)
plt.legend()
plt.xlabel("Re(Ener)")
plt.ylabel("Im(Ener)")
plt.show()

# %%
error = He_2s2_qz_gs - k2
print(f"Mean error: {np.mean(error): 6.4E}")
print(f"Max error:  {np.max(error): 6.4E}")
# Out:
# Mean error:  3.5058E-13+3.4944E-12j
# Max error:   3.4035E-11+1.0236E-11j

# %% [markdown]
# # 2s2
# ## Even-tempered

# %%
w3, k3 = load_traj('data/CSHF_QCHEM/He_2s2_eventemp_qchem.dat')

# %%
He_2s2_even_cxt = CS_RHF_ContextClass(
    S_even_H2,
    T_even_H2,
    V_even_H2,
    eri_even_H2,
    2,
    max_iter=1000,
    threshold=2e-10,
    conv_type="CROP",
)

He_2s2_even_cxt.occupation = np.array([0, 2, 0])
traj_ener_3 = RHF_theta_traj(0.4, 41, He_2s2_even_cxt)

He_2s2_even_ex = np.array(traj_ener_3[1])

# %%
plt.scatter(k3.real, k3.imag, label="Qchem data", marker="o", c="orange")
plt.scatter(
    He_2s2_even_ex.real,
    He_2s2_even_ex.imag,
    label="Implemetation",
    c="RebeccaPurple",
    marker="x",
)
plt.legend()
plt.xlabel("Re(Ener)")
plt.ylabel("Im(Ener)")
plt.show()

# %%
error = He_2s2_even_ex - k3
print(f"Mean error: {np.mean(error): 6.4E}")
print(f"Max error:  {np.max(error): 6.4E}")
# Out:
# Mean error:  5.0772E-13+1.1559E-12j
# Max error:   5.1034E-11-4.5330E-11j

# %% [markdown]
# ## 2s2 aug-cc-pV5Z

# %%
w4, k4 = load_traj("data/CSHF_QCHEM/He_2s2_augqz_qchem.dat")

# %%
He_2s2_qz_ctx = CS_RHF_ContextClass(S_qz_H2, T_qz_H2, V_qz_H2, eri_qz_H2, n_electrons=2)

He_2s2_qz_ctx.occupation = np.array([0, 2, 0])

traj_ener_4 = RHF_theta_traj(0.08, 9, He_2s2_qz_ctx)

He_2s2_qz_ex = np.array(traj_ener_4[1])

# %%
plt.scatter(k4.real, k4.imag, label="Qchem data", marker="o", c="orange")
plt.scatter(
    He_2s2_qz_ex.real,
    He_2s2_qz_ex.imag,
    label="Implemetation",
    c="RebeccaPurple",
    marker="x",
)
plt.legend()
plt.xlabel("Re(Ener)")
plt.ylabel("Im(Ener)")
# plt.xlim([-0.7191, -0.7190])
plt.show()

# %%
error = He_2s2_qz_ex - k4
print(f"Mean error: {np.mean(error): 6.4E}")
print(f"Max error:  {np.max(error): 6.4E}")
# Out:
# Mean error:  1.2423E-12-4.9266E-12j
# Max error:   4.6791E-11+4.7672E-11j
